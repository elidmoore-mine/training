# %%
#Barrett's awesome math program
# importing the numpy module
import numpy as np

n=10000000

# Making a list of integers
org_list = ([1, 2, 3, 4, 5, 6, 7, 8, 9])

# Converting  the list into a numpy array
seq = np.array(org_list)

# Printing content of original sequence
print("Original order of the sequence is :", seq)


##### MUST BE POSITIVE, CAN DUPLICATE LEFT HAND SIDE NUMBERS #####

#set a starting min_value so program doesn't blow up
min_value = 10000

for i in range(0,n):
    # Performing shuffling operation
    np.random.shuffle(seq)
    number_one = seq[0]*100+seq[1]*10+seq[2]
    number_two = seq[3]*100+seq[4]*10+seq[5]
    answer = number_one - number_two
    
    #check to make sure number isn't negative
    if answer>0:
        x =  [int(i) for i in str(answer)]
        if x[0] == x[1] or x[0] == seq[0] or x[0] == seq[1] or x[0] == seq[2] or x[0] == seq[3] or x[0] == seq[4] or x[0] == seq[5] or x[1] == seq[0] or x[1] == seq[1] or x[1] == seq[2] or x[1] == seq[3] or x[1] == seq[4] or x[1] == seq[5]:
            z=1+1
        else:
            if answer<min_value:
                min_value = answer
                final_first = number_one
                final_second = number_two
                final_num = seq[0]*100000+seq[1]*10000+seq[2]*1000+seq[3]*100+seq[4]*10+seq[5]*1
                final_sequence = [int(i) for i in str(final_num)]
next

##### MUST BE POSITIVE, CANNOT DUPLICATE LEFT HAND SIDE NUMBERS #####
#set a starting min_value so program doesn't blow up
min_value_2 = 10000

for i in range(0,n):
    # Performing shuffling operation
    np.random.shuffle(seq)
    number_one = seq[0]*100+seq[1]*10+seq[2]
    number_two = seq[3]*100+seq[4]*10+seq[5]
    answer = number_one - number_two
    
    #check to make sure number isn't negative
    if answer>0:
        x =  [int(i) for i in str(answer)]
        if answer<min_value_2:
            min_value_2 = answer
            final_first_2 = number_one
            final_second_2 = number_two
            final_num_2 = seq[0]*100000+seq[1]*10000+seq[2]*1000+seq[3]*100+seq[4]*10+seq[5]*1
            final_sequence_2 = [int(i) for i in str(final_num)]
next


##### CAN BE NEGATIVE BUT CANNOT DUPLICATE LEFT HAND SIDE NUMBERS #####
#set a starting min_value so program doesn't blow up
min_value_3 = 10000

for i in range(0,n):
    # Performing shuffling operation
    np.random.shuffle(seq)
    number_one = seq[0]*100+seq[1]*10+seq[2]
    number_two = seq[3]*100+seq[4]*10+seq[5]
    answer = number_one - number_two
    
    x =  [int(i) for i in str(abs(answer))]
    if x[0] == x[1] or x[0] == seq[0] or x[0] == seq[1] or x[0] == seq[2] or x[0] == seq[3] or x[0] == seq[4] or x[0] == seq[5] or x[1] == seq[0] or x[1] == seq[1] or x[1] == seq[2] or x[1] == seq[3] or x[1] == seq[4] or x[1] == seq[5]:
        z=1+1
    else:
        if answer<min_value_3:
            min_value_3 = answer
            final_first_3 = number_one
            final_second_3 = number_two
            final_num_3 = seq[0]*100000+seq[1]*10000+seq[2]*1000+seq[3]*100+seq[4]*10+seq[5]*1
            final_sequence_3 = [int(i) for i in str(final_num)]
next


##### CAN BE NEGATIVE AND DUPLICATE LEFT HAND SIDE NUMBERS #####
#set a starting min_value so program doesn't blow up
min_value_4 = 10000

for i in range(0,n):
    # Performing shuffling operation
    np.random.shuffle(seq)
    number_one = seq[0]*100+seq[1]*10+seq[2]
    number_two = seq[3]*100+seq[4]*10+seq[5]
    answer = number_one - number_two
    
    if answer>0:
        x =  [int(i) for i in str(answer)]
    else:
        x =  [int(i) for i in str(abs(answer))]    
        x[0] = -x[0]
        if answer<min_value_4:
            min_value_4 = answer
            final_first_4 = number_one
            final_second_4 = number_two
            final_num_4 = seq[0]*100000+seq[1]*10000+seq[2]*1000+seq[3]*100+seq[4]*10+seq[5]*1
            final_sequence_4 = [int(i) for i in str(final_num)]
next
    
print("If the answer CAN'T use the previous numbers")
print(final_first," - ",final_second," = ",min_value)
print(" ")
print("If the answer CAN use any numbers")
print(final_first_2," - ",final_second_2," = ",min_value_2)
print(" ")
print("If the answer can be a negative number, but CAN'T use the previous numbers")
print(final_first_3," - ",final_second_3," = ",min_value_3)
print(" ")
print("If the answer can be a negative number, but CAN use the previous numbers")
print(final_first_4," - ",final_second_4," = ",min_value_4)
# Out:
# Original order of the sequence is : [1 2 3 4 5 6 7 8 9]
# If the answer CAN'T use the previous numbers
# 718  -  695  =  23
#
# If the answer CAN use any numbers
# 612  -  598  =  14
#
# If the answer can be a negative number, but CAN'T use the previous numbers
# 123  -  976  =  -853
#
# If the answer can be a negative number, but CAN use the previous numbers
# 123  -  987  =  -864
